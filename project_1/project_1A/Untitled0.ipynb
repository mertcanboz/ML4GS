# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions.multivariate_normal import MultivariateNormal
from sklearn.datasets import make_moons

# %%
base_dist = MultivariateNormal(torch.zeros(2), torch.eye(2))

# %%
z = base_dist.sample()
print(z)
# Out:
# tensor([ 0.0665, -0.1686])

# %%
batch_size = 10
# x = torch.Tensor(batch_size, 2)
# for i in range(batch_size):
#   x.add(base_dist.sample())
# x = x * 10000000000
x = torch.Tensor([[1, 2],
                  [3, 4],
                  [5, 6]])
print(x)
x.shape
# Out:
# tensor([[1., 2.],
#         [3., 4.],
#         [5., 6.]])
# torch.Size([3, 2])

# %%
log_scale = nn.Parameter(torch.Tensor([1, 2]))
print(log_scale)
# Out:
# Parameter containing:
# tensor([1., 2.], requires_grad=True)

# %%
shift = nn.Parameter(torch.Tensor([2, 3]))
print(shift)
# Out:
# Parameter containing:
# tensor([2., 3.], requires_grad=True)

# %%
# y = torch.mm(x, x.t())
# 

y = log_scale * x[:, :] + shift
print(y)
# Out:
# tensor([[ 3.,  7.],
#         [ 5., 11.],
#         [ 7., 15.]], grad_fn=<AddBackward0>)

# %%
y = x * log_scale + shift
print(y)
# Out:
# tensor([[ 3.,  7.],
#         [ 5., 11.],
#         [ 7., 15.]], grad_fn=<AddBackward0>)

# %%
y = log_scale * x  + shift
print(y)
# Out:
# tensor([[ 3.,  7.],
#         [ 5., 11.],
#         [ 7., 15.]], grad_fn=<AddBackward0>)

# %%
x = (y - shift) / log_scale
print(x)
# Out:
# tensor([[1., 2.],
#         [3., 4.],
#         [5., 6.]], grad_fn=<DivBackward0>)

# %%
from sklearn.datasets import make_moons
dataset_1 = CircleGaussiansDataset(n_gaussians=1, n_samples=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d141fed6adfb> in <module>()
#       1 from sklearn.datasets import make_moons
# ----> 2 dataset_1 = CircleGaussiansDataset(n_gaussians=1, n_samples=500)
#
# NameError: name 'CircleGaussiansDataset' is not defined

# %%
x tensor([[-1.7924,  1.4232],
        [-0.1067,  0.4870],
        [-1.6837,  0.3379],
        [ 0.3275,  0.1729],
        [ 1.3409, -0.4855],
        [ 1.2897,  2.3060],
        [-0.0732,  0.2745],
        [ 2.1805,  0.0215],

scale tensor([1., 1.], device='cuda:0', grad_fn=<ExpBackward>)
shift tensor([1., 1.], device='cuda:0', grad_fn=<ExpBackward>)
with torch - y, log_det_jac: tensor([[-1.7924,  1.4232],
        [-0.1067,  0.4870],
        [-1.6837,  0.3379],
        [ 0.3275,  0.1729],
        [ 1.3409, -0.4855],
        [ 1.2897,  2.3060],
        [-0.0732,  0.2745],
        [ 2.1805,  0.0215],

tensor(2., device='cuda:0', grad_fn=<SumBackward0>
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-99d969391b1b> in <module>()
# ----> 1 torch.inverse(log_scale)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got -2)

# %%
z_prime = torch.ones(10, 2) * 0.5
z_prime = torch.bernoulli(z_prime)
